# %% [markdown]
# # 1. Introduction 👋
#
# <center><img src="https://images.unsplash.com/photo-1553729459-efe14ef6055d?ixid=MnwxMjA3fDB8MHxwaG90by1wYWdlfHx8fGVufDB8fHx8&ixlib=rb-1.2.1&auto=format&fit=crop&w=2070&q=80" alt="Loan Picture" width="600" height="600"></center><br>
#
# ## Data Set Problems 🤔
#
# 👉 The company seeks **to automate (in real time) the loan qualifying procedure** based on information given by customers while filling out an online application form. It is expected that the development of ML models that can help the company predict loan approval in **accelerating decision-making process** for determining whether an applicant is eligible for a loan or not.
#
# ---
#
# ## Objectives of Notebook 📌
# 👉 **This notebook aims to:**
# *   Analyze customer data provided in data set (EDA)
# *   Build various ML models that can predict loan approval
#
# 👨‍💻 **The machine learning models used in this project are:**
# 1. Logistic Regression
# 2. K-Nearest Neighbour (KNN)
# 3. Support Vector Machine (SVM)
# 4. Naive Bayes
# 5. Decision Tree
# 6. Random Forest
# 7. Gradient Boost
#
# ---
#
# ## Data Set Description 🧾
# 👉 There are **13 variables** in this data set:
# *   **8 categorical** variables,
# *   **4 continuous** variables, and
# *   **1** variable to accommodate the loan ID.
#
# <br>
#
# 👉 The following is the **structure of the data set**.
#
#
# <table style="width:100%">
# <thead>
# <tr>
# <th style="text-align:center; font-weight: bold; font-size:14px">Variable Name</th>
# <th style="text-align:center; font-weight: bold; font-size:14px">Description</th>
# <th style="text-align:center; font-weight: bold; font-size:14px">Sample Data</th>
# </tr>
# </thead>
# <tbody>
# <tr>
# <td><b>Loan_ID</b></td>
# <td>Loan reference number <br> (unique ID)</td>
# <td>LP001002; LP001003; ...</td>
# </tr>
# <tr>
# <td><b>Gender</b></td>
# <td>Applicant gender <br> (Male or Female)</td>
# <td>Male; Female</td>
# </tr>
# <tr>
# <td><b>Married</b></td>
# <td>Applicant marital status <br> (Married or not married)</td>
# <td>Married; Not Married</td>
# </tr>
# <tr>
# <td><b>Dependents</b></td>
# <td>Number of family members</td>
# <td>0; 1; 2; 3+</td>
# </tr>
# <tr>
# <td><b>Education</b></td>
# <td>Applicant education/qualification <br> (graduate or not graduate)</td>
# <td>Graduate; Under Graduate</td>
# </tr>
# <tr>
# <td><b>Self_Employed</b></td>
# <td>Applicant employment status <br> (yes for self-employed, no for employed/others)</td>
# <td>Yes; No</td>
# </tr>
# <tr>
# <td><b>ApplicantIncome</b></td>
# <td>Applicant's monthly salary/income</td>
# <td>5849; 4583; ...</td>
# </tr>
# <tr>
# <td><b>CoapplicantIncome</b></td>
# <td>Additional applicant's monthly salary/income</td>
# <td>1508; 2358; ...</td>
# </tr>
# <tr>
# <td><b>LoanAmount</b></td>
# <td>Loan amount</td>
# <td>128; 66; ...</td>
# </tr>
# <tr>
# <td><b>Loan_Amount_Term</b></td>
# <td>The loan's repayment period (in days)</td>
# <td>360; 120; ...</td>
# </tr>
# <tr>
# <td><b>Credit_History</b></td>
# <td>Records of previous credit history <br> (0: bad credit history, 1: good credit history)</td>
# <td>0; 1</td>
# </tr>
# <tr>
# <td><b>Property_Area</b></td>
# <td>The location of property <br> (Rural/Semiurban/Urban)</td>
# <td>Rural; Semiurban; Urban</td>
# </tr>
# <tr>
# <td><b>Loan_Status</b></td>
# <td>Status of loan <br> (Y: accepted, N: not accepted)</td>
# <td>Y; N</td>
# </tr>
# </tbody>
# </table>
#
# ---
#
# **Like this notebook? You can support me by giving upvote** 😆👍🔼 <br>
# 👉 *More about myself: [linktr.ee/caesarmario_](http://linktr.ee/caesarmario_)*

# %% [markdown]
# # 2. Importing Libraries 📚
# 👉 Importing libraries that will be used in this notebook.

# %%
# !pip install shap

# %%
# # Data
# !pip install folktables
# # ShaRP
# !pip install git+https://github.com/DataResponsibly/ShaRP.git

# %%
from sharp import ShaRP
from sharp.qoi import TopKQoI,FlipQoI,DiffQoI
from sharp.utils import scores_to_ordering

import shap

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import missingno as mso
import seaborn as sns
import warnings
import os
import scipy

from scipy import stats
from scipy.stats import pearsonr
from scipy.stats import ttest_ind
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.preprocessing import MinMaxScaler
from sklearn.model_selection import train_test_split
from imblearn.over_sampling import SMOTE

from sklearn.linear_model import LogisticRegression
from sklearn.neighbors import KNeighborsClassifier
from sklearn.svm import SVC
from sklearn.naive_bayes import CategoricalNB
from sklearn.naive_bayes import GaussianNB
from sklearn.tree import DecisionTreeClassifier
from sklearn.ensemble import RandomForestClassifier
from sklearn.ensemble import GradientBoostingClassifier
from xgboost import XGBClassifier
from sklearn.model_selection import GridSearchCV, RandomizedSearchCV

# %% [markdown]
# # 3. Reading Data Set 👓
# 👉 After importing libraries, we will also import the dataset that will be used.

# %%
df = pd.read_csv("/content/train_u6lujuX_CVtuZ9i (1).csv")
df.head()
# Out:
#     Loan_ID Gender Married Dependents     Education Self_Employed  \
# 0  LP001002   Male      No          0      Graduate            No
# 1  LP001003   Male     Yes          1      Graduate            No
# 2  LP001005   Male     Yes          0      Graduate           Yes
# 3  LP001006   Male     Yes          0  Not Graduate            No
# 4  LP001008   Male      No          0      Graduate            No
#
#    ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0             5849                0.0         NaN             360.0
# 1             4583             1508.0       128.0             360.0
# 2             3000                0.0        66.0             360.0
# 3             2583             2358.0       120.0             360.0
# 4             6000                0.0       141.0             360.0
#
#    Credit_History Property_Area Loan_Status
# 0             1.0         Urban           Y
# 1             1.0         Rural           N
# ...

# %%
print(df.shape)
# Out:
# (614, 13)

# %% [markdown]
# 👉 As can be seen, the **13 columns** are readable. It also can be seen that there are **614 observations** in the data set.

# %% [markdown]
# # 4. Data Exploration 🔍
# 👉 This section will perform data exploration of "raw" data set that has been imported.

# %% [markdown]
# ## 4.1 Categorical Variable 📊
# 👉 The first type of variable that I will explore is categorical variable.

# %% [markdown]
# ### 4.1.1 Loan ID

# %%
# df.Loan_ID.value_counts(dropna=False)

# %% [markdown]
# 👉 It can be seen that there are 614 unique ID in the dataset.

# %% [markdown]
# ### 4.1.2 Gender

# %%
# df.Gender.value_counts(dropna=False)

# %%
# sns.countplot(x="Gender", data=df, palette="hls")
# plt.show()

# %%
# countMale = len(df[df.Gender == 'Male'])
# countFemale = len(df[df.Gender == 'Female'])
# countNull = len(df[df.Gender.isnull()])

# print("Percentage of Male applicant: {:.2f}%".format((countMale / (len(df.Gender))*100)))
# print("Percentage of Female applicant: {:.2f}%".format((countFemale / (len(df.Gender))*100)))
# print("Missing values percentage: {:.2f}%".format((countNull / (len(df.Gender))*100)))

# %% [markdown]
# 👉 From the results above, the number of male applicants is higher compared to female applicants. It also can be seen there are missing values in this column.

# %% [markdown]
# ### 4.1.3 Married

# %%
# df.Married.value_counts(dropna=False)

# %%
# sns.countplot(x="Married", data=df, palette="Paired")
# plt.show()

# %% [markdown]
# 👉 The number of applicants that has been married is higher compared to applicants that hasn't married. It also can be seen there are small number of missing values in this column.

# %%
# countMarried = len(df[df.Married == 'Yes'])
# countNotMarried = len(df[df.Married == 'No'])
# countNull = len(df[df.Married.isnull()])

# print("Percentage of married: {:.2f}%".format((countMarried / (len(df.Married))*100)))
# print("Percentage of Not married applicant: {:.2f}%".format((countNotMarried / (len(df.Married))*100)))
# print("Missing values percentage: {:.2f}%".format((countNull / (len(df.Married))*100)))

# %% [markdown]
# ### 4.1.4 Education

# %%
# df.Education.value_counts(dropna=False)

# %%
# sns.countplot(x="Education", data=df, palette="rocket")
# plt.show()

# %%
# countGraduate = len(df[df.Education == 'Graduate'])
# countNotGraduate = len(df[df.Education == 'Not Graduate'])
# countNull = len(df[df.Education.isnull()])

# print("Percentage of graduate applicant: {:.2f}%".format((countGraduate / (len(df.Education))*100)))
# print("Percentage of Not graduate applicant: {:.2f}%".format((countNotGraduate / (len(df.Education))*100)))
# print("Missing values percentage: {:.2f}%".format((countNull / (len(df.Education))*100)))

# %% [markdown]
# 👉 The number of applicants that has been graduated is higher compared to applicants that hasn't graduated.

# %% [markdown]
# ### 4.1.5 Self Employed

# %%
# df.Self_Employed.value_counts(dropna=False)

# %%
# sns.countplot(x="Self_Employed", data=df, palette="crest")
# plt.show()

# %%
# countNo = len(df[df.Self_Employed == 'No'])
# countYes = len(df[df.Self_Employed == 'Yes'])
# countNull = len(df[df.Self_Employed.isnull()])

# print("Percentage of Not self employed: {:.2f}%".format((countNo / (len(df.Self_Employed))*100)))
# print("Percentage of self employed: {:.2f}%".format((countYes / (len(df.Self_Employed))*100)))
# print("Missing values percentage: {:.2f}%".format((countNull / (len(df.Self_Employed))*100)))

# %% [markdown]
# 👉 The number of applicants that are not self employed is higher compared to applicants that are self employed. It also can be seen, there are missing values in this column.

# %% [markdown]
# ### 4.1.6 Credit History

# %%
# df.Credit_History.value_counts(dropna=False)

# %%
# sns.countplot(x="Credit_History", data=df, palette="viridis")
# plt.show()

# %%
# count1 = len(df[df.Credit_History == 1])
# count0 = len(df[df.Credit_History == 0])
# countNull = len(df[df.Credit_History.isnull()])

# print("Percentage of Good credit history: {:.2f}%".format((count1 / (len(df.Credit_History))*100)))
# print("Percentage of Bad credit history: {:.2f}%".format((count0 / (len(df.Credit_History))*100)))
# print("Missing values percentage: {:.2f}%".format((countNull / (len(df.Credit_History))*100)))

# %% [markdown]
# 👉 The number of applicants that have good credit history is higher compared to applicants that have bad credit history. It also can be seen, there are missing values in this column.

# %% [markdown]
# ### 4.1.7 Property Area

# %%
# df.Property_Area.value_counts(dropna=False)

# %%
# sns.countplot(x="Property_Area", data=df, palette="cubehelix")
# plt.show()

# %%
# countUrban = len(df[df.Property_Area == 'Urban'])
# countRural = len(df[df.Property_Area == 'Rural'])
# countSemiurban = len(df[df.Property_Area == 'Semiurban'])
# countNull = len(df[df.Property_Area.isnull()])

# print("Percentage of Urban: {:.2f}%".format((countUrban / (len(df.Property_Area))*100)))
# print("Percentage of Rural: {:.2f}%".format((countRural / (len(df.Property_Area))*100)))
# print("Percentage of Semiurban: {:.2f}%".format((countSemiurban / (len(df.Property_Area))*100)))
# print("Missing values percentage: {:.2f}%".format((countNull / (len(df.Property_Area))*100)))

# %% [markdown]
# 👉 This column has a balanced distribution between Urban, Rural, and Semiurban property area. It also can be seen there is no missing value.

# %% [markdown]
# ### 4.1.8 Loan Status

# %%
# df.Loan_Status.value_counts(dropna=False)

# %%
# sns.countplot(x="Loan_Status", data=df, palette="YlOrBr")
# plt.show()

# %%
# countY = len(df[df.Loan_Status == 'Y'])
# countN = len(df[df.Loan_Status == 'N'])
# countNull = len(df[df.Loan_Status.isnull()])

# print("Percentage of Approved: {:.2f}%".format((countY / (len(df.Loan_Status))*100)))
# print("Percentage of Rejected: {:.2f}%".format((countN / (len(df.Loan_Status))*100)))
# print("Missing values percentage: {:.2f}%".format((countNull / (len(df.Loan_Status))*100)))

# %% [markdown]
# 👉 The number of approved loans is higher compared to rejected loans . It also can be seen, there is no missing values in this column.

# %% [markdown]
# ### 4.1.9 Loan Amount Term

# %%
# df.Loan_Amount_Term.value_counts(dropna=False)

# %%
# sns.countplot(x="Loan_Amount_Term", data=df, palette="rocket")
# plt.show()

# %%
# count12 = len(df[df.Loan_Amount_Term == 12.0])
# count36 = len(df[df.Loan_Amount_Term == 36.0])
# count60 = len(df[df.Loan_Amount_Term == 60.0])
# count84 = len(df[df.Loan_Amount_Term == 84.0])
# count120 = len(df[df.Loan_Amount_Term == 120.0])
# count180 = len(df[df.Loan_Amount_Term == 180.0])
# count240 = len(df[df.Loan_Amount_Term == 240.0])
# count300 = len(df[df.Loan_Amount_Term == 300.0])
# count360 = len(df[df.Loan_Amount_Term == 360.0])
# count480 = len(df[df.Loan_Amount_Term == 480.0])
# countNull = len(df[df.Loan_Amount_Term.isnull()])

# print("Percentage of 12: {:.2f}%".format((count12 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 36: {:.2f}%".format((count36 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 60: {:.2f}%".format((count60 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 84: {:.2f}%".format((count84 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 120: {:.2f}%".format((count120 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 180: {:.2f}%".format((count180 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 240: {:.2f}%".format((count240 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 300: {:.2f}%".format((count300 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 360: {:.2f}%".format((count360 / (len(df.Loan_Amount_Term))*100)))
# print("Percentage of 480: {:.2f}%".format((count480 / (len(df.Loan_Amount_Term))*100)))
# print("Missing values percentage: {:.2f}%".format((countNull / (len(df.Loan_Amount_Term))*100)))

# %% [markdown]
# 👉 As can be seen from the results, **the 360 days loan duration is the most popular** compared to others.

# %% [markdown]
# ## 4.2 Numerical Variable 🔢
# 👉 The second variable that I will explore is categorical variable.

# %% [markdown]
# ### 4.2.1 Describe Numerical Variable 🔎
# 👉 This section will show mean, count, std, min, max and others using describe function.

# %%
# df[['ApplicantIncome','CoapplicantIncome','LoanAmount']].describe()

# %% [markdown]
# ### 4.2.2 Distribution of Numerical Variable 📈
# 👉 In this section, I will show the distribution of numerical variable using histogram and violin plot.

# %% [markdown]
# #### 4.2.2.1 Histogram Distribution 📉

# %%
# sns.set(style="darkgrid")
# fig, axs = plt.subplots(2, 2, figsize=(10, 8))

# sns.histplot(data=df, x="ApplicantIncome", kde=True, ax=axs[0, 0], color='green')
# sns.histplot(data=df, x="CoapplicantIncome", kde=True, ax=axs[0, 1], color='skyblue')
# sns.histplot(data=df, x="LoanAmount", kde=True, ax=axs[1, 0], color='orange');

# %% [markdown]
# #### 4.2.2.2 Violin Plot 🎻

# %%
# sns.set(style="darkgrid")
# fig, axs1 = plt.subplots(2, 2, figsize=(10, 10))

# sns.violinplot(data=df, y="ApplicantIncome", ax=axs1[0, 0], color='green')
# sns.violinplot(data=df, y="CoapplicantIncome", ax=axs1[0, 1], color='skyblue')
# sns.violinplot(data=df, y="LoanAmount", ax=axs1[1, 0], color='orange');

# %% [markdown]
# *   The distribution of **Applicant income, Co Applicant Income, and Loan Amount** are **positively skewed** and **it has outliers** (can be seen from both histogram and violin plot).
# *   The distribution of **Loan Amount Term** is **negativly skewed** and **it has outliers.**

# %% [markdown]
# ## 4.3 Other Exploration 💹
# 👉 This section will show additional exploration from each variables. The additional exploration are:
# *   Bivariate analysis (categorical w/ categorical, categroical w/ numerical, and numerical w/ numerical)
# *   Heatmap

# %% [markdown]
# ### 4.3.1 Heatmap 🔥

# %%
# df

# %%
# plt.figure(figsize=(10,7))
# sns.heatmap(df.corr(), annot=True, cmap='inferno');

# %% [markdown]
# 👉 There is positive correlation between Loan Amount and Applicant Income

# %% [markdown]
# ### 4.3.2 Categorical 📊 - Categorical 📊

# %%
# pd.crosstab(df.Gender,df.Married).plot(kind="bar", stacked=True, figsize=(5,5), color=['#f64f59','#12c2e9'])
# plt.title('Gender vs Married')
# plt.xlabel('Gender')
# plt.ylabel('Frequency')
# plt.xticks(rotation=0)
# plt.show()

# %% [markdown]
# 👉 Most male applicants are already married compared to female applicants. Also, the number of not married male applicants are higher compare to female applicants that had not married.

# %%
# pd.crosstab(df.Self_Employed,df.Credit_History).plot(kind="bar", stacked=True, figsize=(5,5), color=['#544a7d','#ffd452'])
# plt.title('Self Employed vs Credit History')
# plt.xlabel('Self Employed')
# plt.ylabel('Frequency')
# plt.legend(["Bad Credit", "Good Credit"])
# plt.xticks(rotation=0)
# plt.show()

# %% [markdown]
# 👉 Most not self employed applicants have good credit compared to self employed applicants.

# %%
# pd.crosstab(df.Property_Area,df.Loan_Status).plot(kind="bar", stacked=True, figsize=(5,5), color=['#333333','#dd1818'])
# plt.title('Property Area vs Loan Status')
# plt.xlabel('Property Area')
# plt.ylabel('Frequency')
# plt.xticks(rotation=0)
# plt.show()

# %% [markdown]
# 👉 Most of loan that got accepted has property in Semiurban compared to Urban and Rural.

# %% [markdown]
# ### 4.3.3 Categorical 📊- Numerical 📈

# %%
# sns.boxplot(x="Loan_Status", y="ApplicantIncome", data=df, palette="mako");

# %% [markdown]
# 👉 It can be seen that there are lots of outliers in Applicant Income, and the distribution also positively skewed

# %%
# sns.boxplot(x="CoapplicantIncome", y="Loan_Status", data=df, palette="rocket");

# %% [markdown]
# 👉 It's clear that Co Applicant Income has a number of outliers, and the distribution is also positively skewed.

# %%
# sns.boxplot(x="Loan_Status", y="LoanAmount", data=df, palette="YlOrBr");

# %% [markdown]
# 👉 As can be seen, Co Applicant Income has a high number of outliers, and the distribution is also positively skewed.

# %% [markdown]
# ### 4.3.4 Numerical 📈 - Numerical 📈

# %%
# df.plot(x='ApplicantIncome', y='CoapplicantIncome', style='o')
# plt.title('Applicant Income - Co Applicant Income')
# plt.xlabel('ApplicantIncome')
# plt.ylabel('CoapplicantIncome')
# plt.show()
# print('Pearson correlation:', df['ApplicantIncome'].corr(df['CoapplicantIncome']))
# print('T Test and P value: \n', stats.ttest_ind(df['ApplicantIncome'], df['CoapplicantIncome']))

# %% [markdown]
# *   There is **negative correlation** between Applicant income and Co Applicant Income.
# *   The correlation coefficient is **significant** at the 95 per cent confidence interval, as it has a **p-value of 1.46**

# %% [markdown]
# ## 4.4 Null Values 🚫

# %%
# df.isnull().sum()

# %%
# plt.figure(figsize = (24, 5))
# axz = plt.subplot(1,2,2)
# mso.bar(df, ax = axz, fontsize = 12);

# %% [markdown]
# 👉 Previously, the null values has been explored for Categorical Variables. In this section, the null values has been explored **for all variables** in the dataset.

# %% [markdown]
# # 5. Data Preprocessing ⚙

# %% [markdown]
# ## 5.1 Drop Unecessary Variables 🔻
# 👉 Unecessary variables will be dropped in this section.

# %%
df = df.drop(['Loan_ID'], axis = 1)

# %% [markdown]
# ## 5.2 Data Imputation 📝
# 👉 Imputation is a technique for substituting an estimated value for missing values in a dataset. In this section, the imputation will be performed for variables that have missing values.

# %% [markdown]
# ### 5.2.1 Categorical Variables 📊
# 👉 In this section, the imputation for categorical variables will be performed using **mode**.

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(1, 3, figsize=(10,4))

sns.histplot(data=df, x="ApplicantIncome", kde=True, ax=axs[0], color='green')
sns.histplot(data=df, x="CoapplicantIncome", kde=True, ax=axs[1], color='skyblue')
sns.histplot(data=df, x="LoanAmount", kde=True, ax=axs[2], color='orange');

# %%
df['Gender'].fillna(df['Gender'].mode()[0],inplace=True)
df['Married'].fillna(df['Married'].mode()[0],inplace=True)
df['Dependents'].fillna(df['Dependents'].mode()[0],inplace=True)
df['Self_Employed'].fillna(df['Self_Employed'].mode()[0],inplace=True)
df['Credit_History'].fillna(df['Credit_History'].mode()[0],inplace=True)
df['Loan_Amount_Term'].fillna(df['Loan_Amount_Term'].mode()[0],inplace=True)

# %% [markdown]
# ### 5.2.2 Numerical Variables 📈
# 👉 The next section is imputation for numerical variables using **mean**.

# %%
df['LoanAmount'].fillna(df['LoanAmount'].mean(),inplace=True)

# %% [markdown]
# ## 5.3 One-hot Encoding 🔧
# 👉 In this section, I will **transform categorical variables into a form that could be provided by ML algorithms to do a better prediction.**

# %%
df = pd.get_dummies(df)

# Drop columns
df = df.drop(['Gender_Female', 'Married_No', 'Education_Not Graduate',
              'Self_Employed_No', 'Loan_Status_N'], axis = 1)

# Rename columns name
new = {'Gender_Male': 'Gender', 'Married_Yes': 'Married',
       'Education_Graduate': 'Education', 'Self_Employed_Yes': 'Self_Employed',
       'Loan_Status_Y': 'Loan_Status'}

df.rename(columns=new, inplace=True)

# %% [markdown]
# ## 5.3 Remove Outliers & Infinite values 🚮
# 👉 Since there are outliers, **the outliers will be removed**. <br>

# %% [markdown]
# #WRONG IMPLIMENTATION!

# %% [markdown]
# This code snippet performs outlier removal using the interquartile range (IQR) method. While outlier removal can help in improving model performance and data quality, it can also introduce bias and impact fairness in several ways:
#
# Bias Introduction:
# Outlier removal based on IQR can bias the dataset by removing instances that are valid but extreme. These instances may represent important real-world scenarios and should not be arbitrarily discarded.
# For example, if there are outliers in loan amount or income, removing them might skew the data, making it less representative of the population being modeled.
# Impact on Fairness:
# Outlier removal can disproportionately affect certain groups in the dataset, leading to fairness issues.
# For instance, if certain demographic groups have higher income or loan amounts on average, removing outliers based on these variables could unfairly disadvantage those groups.
# Data Loss:
# Removing outliers can lead to data loss, especially if there are a significant number of outliers or if they represent important patterns or trends in the data.
# Loss of valuable information may affect model training and prediction accuracy, especially if outliers contain useful signals or insights.
# Overfitting Reduction:
# While outlier removal can help in reducing overfitting, it may also remove valuable information that can improve the model's generalization ability.

# %%
# Drop non-numeric columns
numeric_df = df.select_dtypes(include=['number'])

# Calculate quartiles and IQR
Q1 = numeric_df.quantile(0.25)
Q3 = numeric_df.quantile(0.75)
IQR = Q3 - Q1

# Filter outliers
df_o = df[~((numeric_df < (Q1 - 1.5 * IQR)) | (numeric_df > (Q3 + 1.5 * IQR))).any(axis=1)]

# %%
df.shape, df_o.shape
# Out:
# ((614, 17), (406, 17))

# %% [markdown]
# ## 5.4 Skewed Distribution Treatment 📐
# 👉 In previous section, it already shown that **distribution for ApplicantIncome, CoapplicantIncome, and LoanAmount is positively skewed**. <br>
# 👉 I will use **square root transformation** to normalized the distribution.

# %% [markdown]
# #WRONG IMPLIMENTATION!

# %% [markdown]
# Using a square root transformation to normalize skewed distributions can introduce bias in the data. Here's how:
#
# Impact on Outliers:
# Square root transformation can effectively reduce the impact of extreme values (outliers) in the data. However, it might not completely eliminate their influence.
# Outliers may still have a substantial effect on the transformed data, especially if they are present in high frequency or magnitude.
# Distortion of Relationships:
# Transformation alters the relationships between variables. In some cases, it may exaggerate or attenuate the relationships between variables.
# For example, if there is a non-linear relationship between ApplicantIncome and another variable, square root transformation may distort or magnify this relationship.
# Non-linear Transformations:
# While square root transformation can reduce skewness, it imposes a specific non-linear structure on the data.
# This transformation may not adequately capture the underlying relationships or distributional properties of the original data.
# Interpretability:
# Transformed variables may be less interpretable. For instance, interpreting the effect of a one-unit change in the square root of ApplicantIncome may be less intuitive compared to the original ApplicantIncome.
# Bias in Predictive Models:
# Square root transformation may introduce bias in predictive models if the relationship between the transformed feature and the target variable is not well-captured by the transformation.
# This bias may lead to inaccuracies in model predictions, especially if the transformation disproportionately affects certain segments of the data.
# Assumptions Violation:
# Using transformations assumes that the data conform to certain distributional assumptions. If these assumptions are violated, the transformed data may not accurately represent the underlying reality.

# %%
df.ApplicantIncome = np.sqrt(df.ApplicantIncome)
df.CoapplicantIncome = np.sqrt(df.CoapplicantIncome)
df.LoanAmount = np.sqrt(df.LoanAmount)

# %%
# Square Root Transformation
df_o.ApplicantIncome = np.sqrt(df_o.ApplicantIncome)
df_o.CoapplicantIncome = np.sqrt(df_o.CoapplicantIncome)
df_o.LoanAmount = np.sqrt(df_o.LoanAmount)
# Out:
# <ipython-input-153-aa109026abdf>:3: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_o.ApplicantIncome = np.sqrt(df_o.ApplicantIncome)
# <ipython-input-153-aa109026abdf>:4: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
#   df_o.CoapplicantIncome = np.sqrt(df_o.CoapplicantIncome)
# <ipython-input-153-aa109026abdf>:5: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# ...

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

sns.histplot(data=df_o, x="ApplicantIncome", kde=True, ax=axs[0, 0], color='green')
sns.histplot(data=df_o, x="CoapplicantIncome", kde=True, ax=axs[0, 1], color='skyblue')
sns.histplot(data=df_o, x="LoanAmount", kde=True, ax=axs[1, 0], color='orange');

# %%
sns.set(style="darkgrid")
fig, axs = plt.subplots(2, 2, figsize=(10, 8))

sns.histplot(data=df, x="ApplicantIncome", kde=True, ax=axs[0, 0], color='green')
sns.histplot(data=df, x="CoapplicantIncome", kde=True, ax=axs[0, 1], color='skyblue')
sns.histplot(data=df, x="LoanAmount", kde=True, ax=axs[1, 0], color='orange');

# %% [markdown]
# 👉 As can be seen, the distribution after using log transformation are much better compared to original distribution.

# %% [markdown]
# ## 5.5 Features Separating ➗
# 👉 Dependent features (Loan_Status) will be seperated from independent features.

# %%
X_o = df_o.drop(["Loan_Status"], axis=1)
y_o = df_o["Loan_Status"]

# %%
X = df.drop(["Loan_Status"], axis=1)
y = df["Loan_Status"]

# %% [markdown]
# ## 5.6 SMOTE Technique 🔨
# 👉 In previous exploration, it can be seen that **the number between approved and rejected loan is imbalanced**. In this section, **oversampling technique will be used to avoid overfitting**,

# %% [markdown]
# #WRONG IMPLIMENTATION!

# %% [markdown]
# Using SMOTE on the entire dataset (X) is generally not recommended for several reasons:
#
# Data Leakage:
# SMOTE generates synthetic samples to balance the classes by interpolating between existing minority class samples. If SMOTE is applied to the entire dataset, information from the test set can leak into the training process, leading to overfitting and overly optimistic performance estimates.
# Models trained on data with synthetic samples created from the entire dataset may not generalize well to unseen data.
# Synthetic Samples in Test Set:
# When SMOTE is applied to the entire dataset, the synthetic samples generated by SMOTE will be included in the test set. This can lead to biased evaluation results since the model has seen synthetic samples during training.
# The test set should remain independent of the training process to accurately evaluate model performance.
# Increased Complexity and Overfitting:
# SMOTE may introduce unnecessary complexity to the majority class by generating synthetic samples. This can lead to overfitting and reduced model generalization.
# SMOTE should be applied only to the minority class to balance the class distribution without introducing unnecessary complexity to the majority class.
# Inflation of Class Ratios:
# Applying SMOTE to the entire dataset may lead to an excessive inflation of class ratios, making the dataset unrepresentative of the true underlying distribution.
# This can lead to skewed evaluations and misleading conclusions about model performance.

# %% [markdown]
# Yes, applying SMOTE to the X_train data can introduce bias with regard to fairness, especially if the original dataset already contains bias.
#
# Here's how SMOTE may introduce bias in fairness:
#
# Amplification of Existing Bias:
# If the original dataset contains biases related to sensitive attributes (such as gender or race), applying SMOTE can potentially amplify these biases.
# SMOTE generates synthetic samples by interpolating between existing minority class samples, which may inherit the biases present in the original data.
# Impact on Fairness Metrics:
# Fairness metrics, such as disparate impact or equal opportunity, may be affected by the introduction of synthetic samples through SMOTE.
# If the synthetic samples created by SMOTE disproportionately affect certain groups, it can lead to biased outcomes in fairness evaluations.
# Model Performance Bias:
# Biases introduced by SMOTE can affect the performance of machine learning models, leading to disparities in predictions across different groups.
# Models trained on biased data may produce unfair outcomes, favoring or disadvantaging certain groups in their predictions.

# %%
X_aug, y_aug = SMOTE().fit_resample(X_o, y_o)

# %%
sns.set_theme(style="darkgrid")
sns.countplot(y=y, data=df, palette="coolwarm")
plt.ylabel('Loan Status')
plt.xlabel('Total')
plt.show()
# Out:
# <ipython-input-159-464dc99333fe>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=y, data=df, palette="coolwarm")

# %%
sns.set_theme(style="darkgrid")
sns.countplot(y=y_aug, data=df_o, palette="coolwarm")
plt.ylabel('Loan Status')
plt.xlabel('Total')
plt.show()
# Out:
# <ipython-input-160-bea1088d2418>:2: FutureWarning:
#
# Passing `palette` without assigning `hue` is deprecated and will be removed in v0.14.0. Assign the `y` variable to `hue` and set `legend=False` for the same effect.
#
#   sns.countplot(y=y_aug, data=df_o, palette="coolwarm")

# %% [markdown]
# 👉 As can be seen, the distrubtion of Loan status are now **balanced**.

# %% [markdown]
# ## 5.7 Data Normalization ⚖
# 👉 In this section, data normalization will be performed **to normalize the range of independent variables or features of data**.

# %% [markdown]
# #WRONG IMPLIMENTATION!

# %% [markdown]
# When using MinMaxScaler to scale the features, it's important to fit the scaler on the training data (X_train) and then transform both the training and test data.
#
# Here's why:
#
# Prevent Data Leakage:
# Fitting the scaler on the entire dataset (X) may lead to data leakage because information from the test set is used during the training process. This can result in overly optimistic performance estimates and poor generalization to unseen data.
# Maintain Consistency:
# Scaling should be performed consistently on both training and test datasets to ensure that the same scaling factors are applied to all features. This maintains the integrity of the data and ensures that the model learns from and generalizes well to unseen data.
# Realistic Evaluation:
# Scaling should reflect the distribution of the training data to provide a realistic representation of the data for model training. Scaling the test set separately could lead to different data distributions between the training and test sets, affecting model performance evaluation.

# %%
X_aug = MinMaxScaler().fit_transform(X_aug)

# %%
X_train, X_test, y_train, y_test = train_test_split(X_aug, y_aug, test_size = 0.2, random_state = 0)

# %% [markdown]
# ## 5.8 Splitting Data Set 🪓
# 👉 The data set will be split into **80% train and 20% test**.

# %%
X_traint, X_testt, y_traint, y_testt = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
X_traint, y_traint = SMOTE().fit_resample(X_traint, y_traint)
scaler = MinMaxScaler()

# Fit the scaler on the training data
scaler.fit(X_traint)

# Transform both the training and test data
X_traint = scaler.transform(X_traint)
X_testt = scaler.transform(X_testt)

# %% [markdown]
# # 6. Models 🛠

# %% [markdown]
# ## 6.1 Logistic Regression

# %%
LRclassifiert = LogisticRegression(solver='saga', max_iter=500, random_state=1)
LRclassifiert.fit(X_traint, y_traint)

y_predt = LRclassifiert.predict(X_testt)

print(classification_report(y_testt, y_predt))
print(confusion_matrix(y_testt, y_predt))

from sklearn.metrics import accuracy_score
LRAcct = accuracy_score(y_predt,y_testt)
print('LR accuracy: {:.2f}%'.format(LRAcct*100))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.88      0.42      0.57        33
#         True       0.82      0.98      0.89        90
#
#     accuracy                           0.83       123
#    macro avg       0.85      0.70      0.73       123
# weighted avg       0.84      0.83      0.81       123
#
# [[14 19]
#  [ 2 88]]
# LR accuracy: 82.93%

# %%
LRclassifier = LogisticRegression(solver='saga', max_iter=500, random_state=1)
LRclassifier.fit(X_train, y_train)

y_pred = LRclassifier.predict(X_test)

print(classification_report(y_test, y_pred))
print(confusion_matrix(y_test, y_pred))

from sklearn.metrics import accuracy_score
LRAcc = accuracy_score(y_pred,y_test)
print('LR accuracy: {:.2f}%'.format(LRAcc*100))
# Out:
#               precision    recall  f1-score   support
#
#        False       0.96      0.70      0.81        67
#         True       0.75      0.97      0.85        62
#
#     accuracy                           0.83       129
#    macro avg       0.85      0.83      0.83       129
# weighted avg       0.86      0.83      0.83       129
#
# [[47 20]
#  [ 2 60]]
# LR accuracy: 82.95%

# %% [markdown]
# ## 6.2 K-Nearest Neighbour (KNN)

# %%
# scoreListknn = []
# for i in range(1,21):
#     KNclassifier = KNeighborsClassifier(n_neighbors = i)
#     KNclassifier.fit(X_train, y_train)
#     scoreListknn.append(KNclassifier.score(X_test, y_test))

# plt.plot(range(1,21), scoreListknn)
# plt.xticks(np.arange(1,21,1))
# plt.xlabel("K value")
# plt.ylabel("Score")
# plt.show()
# KNAcc = max(scoreListknn)
# print("KNN best accuracy: {:.2f}%".format(KNAcc*100))

# %% [markdown]
# ## 6.3 Support Vector Machine (SVM)

# %%
# SVCclassifier = SVC(kernel='rbf', max_iter=500)
# SVCclassifier.fit(X_train, y_train)

# y_pred = SVCclassifier.predict(X_test)

# print(classification_report(y_test, y_pred))
# print(confusion_matrix(y_test, y_pred))

# from sklearn.metrics import accuracy_score
# SVCAcc = accuracy_score(y_pred,y_test)
# print('SVC accuracy: {:.2f}%'.format(SVCAcc*100))

# %% [markdown]
# ## 6.4 Naive Bayes

# %% [markdown]
# ### 6.4.1 Categorical NB

# %%
# NBclassifier1 = CategoricalNB()
# NBclassifier1.fit(X_train, y_train)

# y_pred = NBclassifier1.predict(X_test)

# print(classification_report(y_test, y_pred))
# print(confusion_matrix(y_test, y_pred))

# from sklearn.metrics import accuracy_score
# NBAcc1 = accuracy_score(y_pred,y_test)
# print('Categorical Naive Bayes accuracy: {:.2f}%'.format(NBAcc1*100))

# %% [markdown]
# ### 6.4.2 Gaussian NB

# %%
# NBclassifier2 = GaussianNB()
# NBclassifier2.fit(X_train, y_train)

# y_pred = NBclassifier2.predict(X_test)

# print(classification_report(y_test, y_pred))
# print(confusion_matrix(y_test, y_pred))

# from sklearn.metrics import accuracy_score
# NBAcc2 = accuracy_score(y_pred,y_test)
# print('Gaussian Naive Bayes accuracy: {:.2f}%'.format(NBAcc2*100))

# %% [markdown]
# ## 6.5 Decision Tree

# %%
# scoreListDT = []
# for i in range(2,21):
#     DTclassifier = DecisionTreeClassifier(max_leaf_nodes=i)
#     DTclassifier.fit(X_train, y_train)
#     scoreListDT.append(DTclassifier.score(X_test, y_test))

# plt.plot(range(2,21), scoreListDT)
# plt.xticks(np.arange(2,21,1))
# plt.xlabel("Leaf")
# plt.ylabel("Score")
# plt.show()
# DTAcc = max(scoreListDT)
# print("Decision Tree Accuracy: {:.2f}%".format(DTAcc*100))

# %% [markdown]
# ## 6.6 Random Forest

# %%
X_traint.shape, X_train.shape, X_testt.shape, X_test.shape
# Out:
# ((664, 16), (515, 16), (123, 16), (129, 16))

# %%
scoreListRF = {"correct_(wrong impute)": 0, "wrong_outlier_and_normalization": 0}
for i in range(20,21):
    RFclassifiert = RandomForestClassifier(n_estimators = 1000, random_state = 1, max_leaf_nodes=i)
    RFclassifiert.fit(X_traint, y_traint)
    scoreListRF["correct_(wrong impute)"] = RFclassifiert.score(X_test, y_test)

# %%
for i in range(20,21):
    RFclassifier = RandomForestClassifier(n_estimators = 1000, random_state = 1, max_leaf_nodes=i)
    RFclassifier.fit(X_train, y_train)
    scoreListRF["wrong_outlier_and_normalization"] = RFclassifier.score(X_test, y_test)

# plt.plot(range(2,25), scoreListRF)
# plt.xticks(np.arange(2,25,1))
# plt.xlabel("RF Value")
# plt.ylabel("Score")
# plt.show()
# RFAcc = max(scoreListRF)
# print("Random Forest Accuracy:  {:.2f}%".format(RFAcc*100))

# %%
scoreListRF
# Out:
# {'correct_(wrong impute)': 0.5193798449612403,
#  'wrong_outlier_and_normalization': 0.8217054263565892}

# %%
scoreListRF
# Out:
# {'correct_(wrong impute)': 0.5193798449612403,
#  'wrong_outlier_and_normalization': 0.8217054263565892}

# %%
y_predt = RFclassifiert.predict(X_testt)
print("Classification report: \n",classification_report(y_testt, y_predt))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#        False       0.74      0.42      0.54        33
#         True       0.82      0.94      0.88        90
#
#     accuracy                           0.80       123
#    macro avg       0.78      0.68      0.71       123
# weighted avg       0.80      0.80      0.79       123

# %%
y_pred = RFclassifier.predict(X_test)
print("Classification report: \n",classification_report(y_test, y_pred))
# Out:
# Classification report:
#                precision    recall  f1-score   support
#
#        False       0.82      0.84      0.83        67
#         True       0.82      0.81      0.81        62
#
#     accuracy                           0.82       129
#    macro avg       0.82      0.82      0.82       129
# weighted avg       0.82      0.82      0.82       129

# %% [markdown]
# ## 6.7 Gradient Boosting

# %%
# paramsGB={'n_estimators':[100,200,300,400,500],
#       'max_depth':[1,2,3,4,5],
#       'subsample':[0.5,1],
#       'max_leaf_nodes':[2,5,10,20,30,40,50]}

# %%
# GB = RandomizedSearchCV(GradientBoostingClassifier(), paramsGB, cv=20)
# GB.fit(X_train, y_train)

# %%
# print(GB.best_estimator_)
# print(GB.best_score_)
# print(GB.best_params_)
# print(GB.best_index_)

# %%
# GBclassifier = GradientBoostingClassifier(subsample=0.5, n_estimators=400, max_depth=4, max_leaf_nodes=10)
# GBclassifier.fit(X_train, y_train)

# y_pred = GBclassifier.predict(X_test)

# print(classification_report(y_test, y_pred))
# print(confusion_matrix(y_test, y_pred))

# from sklearn.metrics import accuracy_score
# GBAcc = accuracy_score(y_pred,y_test)
# print('Gradient Boosting accuracy: {:.2f}%'.format(GBAcc*100))

# %% [markdown]
# # 7. Model Comparison 👀

# %%
# compare = pd.DataFrame({'Model': ['Logistic Regression', 'K Neighbors',
#                                   'SVM', 'Categorical NB',
#                                   'Gaussian NB', 'Decision Tree',
#                                   'Random Forest', 'Gradient Boost'],
#                         'Accuracy': [LRAcc*100, KNAcc*100, SVCAcc*100,
#                                      NBAcc1*100, NBAcc2*100, DTAcc*100,
#                                      RFAcc*100, GBAcc*100]})
# compare.sort_values(by='Accuracy', ascending=False)

# %% [markdown]
# 👉 In general, it can be seen that **all models can achieve up to 70% accuracy**. <br>
# 👉 The highest accuracy is **93%%**. <br><br>
# 👉 If you have any suggestions to **improve** these models, we can *discuss in the comments* :).

# %% [markdown]
# ---
#
# **Like this notebook? You can support me by giving upvote** 😆👍🔼 <br>
# 👉 *More about myself: [linktr.ee/caesarmario_](http://linktr.ee/caesarmario_)*<br><br>
# #### 🎈 Check out my work on GitHub using similar data sets with SAS studio [here](https://github.com/caesarmario/loan-prediction-SAS-studio).

# %% [markdown]
# #SHAP

# %%
df.shape, df_o.shape
# Out:
# ((614, 17), (396, 17))

# %%
# # graphviz is installed already, but need lib too
# !apt install libgraphviz-dev
# !pip install pygraphviz
# !SETUPTOOLS_USE_DISTUTILS=stdlib pip install git+https://github.com/stefan-grafberger/mlinspect.git@c2207ef058e5fb28cc74c72c7c9f3deed04fc639
# !pip install tensorflow==2.15.0
# !pip install keras==2.15.0
# !pip install jinja2==3.0.3

# %%
# !pip install aequitas

# %%
import urllib
from inspect import cleandoc

import os
# from mlinspect.utils import get_project_root

# from mlinspect import PipelineInspector
# from mlinspect.checks import NoBiasIntroducedFor, NoIllegalFeatures
# from mlinspect.inspections import MaterializeFirstOutputRows

# %%
from folktables import ACSDataSource, ACSEmployment, ACSIncome, ACSPublicCoverage, ACSMobility, ACSTravelTime
from sklearn.preprocessing import StandardScaler
import seaborn as sns

import matplotlib.pyplot as plt
from IPython.display import clear_output

from aequitas.group import Group
from aequitas.bias import Bias
from aequitas.fairness import Fairness
from aequitas.plotting import Plot

# %%
# from mlinspect.inspections import FairnessEvaluation
import shap
import pickle

# %%
model = RFclassifier
X_s = X_test

# %% [markdown]
# #SHAP WATERFALL

# %%
# # Calculate predicted probabilities for the test set
# y_pred_proba = model.predict_proba(X_test)[:, 1]  # Probability of class 1

# # Find index with highest and lowest predicted probability
# itop = np.argmax(y_pred_proba)
# ibottom = np.argmin(y_pred_proba)

# # Use X_test (X_s) for SHAP values
# X_s = X_test

# # SHAP explanation
# # Summarize the background data using a smaller subset
# # background = shap.sample(X_s, 50)
# background = shap.kmeans(X_s, 50)  # Use 50 samples for background summary
# explainer = shap.KernelExplainer(model.predict, background)
# shap_values = explainer.shap_values(X_s)

# %%
explainer = shap.Explainer(model, X_train)
shap_values = explainer.shap_values(X_test)
# Out:
# 100%|===================| 257/258 [00:18<00:00]

# %%
shap_values.shape
# Out:
# (129, 16, 2)

# %%
shap_values_reshaped = np.transpose(shap_values, (0, 2, 1))

print(shap_values_reshaped.shape)
# Out:
# (129, 2, 16)

# %%
with open('shap_values_reshaped.pkl', 'wb') as f:
    pickle.dump(shap_values_reshaped, f)

# %%
with open('shap_values_reshaped.pkl', 'rb') as f:
    shap_values_reshaped = pickle.load(f)

# %%
y_test[0], y_pred[0]
# Out:
# (False, False)

# %%
# Create waterfall plot
shap.waterfall_plot(shap.Explanation(values=shap_values_reshaped[0][1][:],
                                base_values=explainer.expected_value[1],
                                data=X_test_df.iloc[0]), max_display=10)

# Show the plot
plt.show()

# %%
y_test[1], y_pred[1]
# Out:
# (True, False)

# %%
# Create Explanation object for the first instance in the test set
explanation = shap.Explanation(values=shap_values_reshaped[1][1][:],
                                base_values=explainer.expected_value[1],
                                data=X_test_df.iloc[1])

# Create waterfall plot
shap.waterfall_plot(explanation, max_display=10)

# Show the plot
plt.show()

# %%
# y_pred = model.predict(X_test)

# %%
y_test.iloc[3], y_pred[3]
# Out:
# (True, True)

# %%
# Create Explanation object for the first instance in the test set
explanation = shap.Explanation(values=shap_values_reshaped[3][1][:],
                                base_values=explainer.expected_value[1],
                                data=X_test_df.iloc[3])

# Create waterfall plot
shap.waterfall_plot(explanation, max_display=10)

# Show the plot
plt.show()

# %%
X_test_df

# %% [markdown]
# #RANDOM FOREST FEATURE IMPORTANCES

# %%
importances = model.feature_importances_

# Sort feature importances in descending order
indices = np.argsort(importances)[::-1]

# Get column names
column_names = X_test_df.columns[:-1]  # Assuming X is a DataFrame

# Plot
plt.figure(figsize=(10, 6))
plt.title("Feature Importances")
plt.bar(range(X_test.shape[1]), importances[indices], color="b", align="center")
plt.xticks(range(X_test.shape[1]), [column_names[i] for i in indices], rotation=45, ha='right')  # Display column names
plt.xlabel("Features")
plt.ylabel("Importance Score")
plt.tight_layout()
plt.show()

# %% [markdown]
# #AQ

# %%
df
# Out:
#      ApplicantIncome  CoapplicantIncome  LoanAmount  Loan_Amount_Term  \
# 0          76.478755           0.000000   12.100089             360.0
# 1          67.697858          38.832976   11.313708             360.0
# 2          54.772256           0.000000    8.124038             360.0
# 3          50.823223          48.559242   10.954451             360.0
# 4          77.459667           0.000000   11.874342             360.0
# ..               ...                ...         ...               ...
# 609        53.851648           0.000000    8.426150             360.0
# 610        64.078077           0.000000    6.324555             180.0
# 611        89.844310          15.491933   15.905974             360.0
# 612        87.080423           0.000000   13.674794             360.0
# 613        67.697858           0.000000   11.532563             360.0
#
#      Credit_History  Gender  Married  Dependents_0  Dependents_1  \
# ...

# %%
X_test.shape
# Out:
# (129, 16)

# %%
df.columns
# Out:
# Index(['ApplicantIncome', 'CoapplicantIncome', 'LoanAmount',
#        'Loan_Amount_Term', 'Credit_History', 'Gender', 'Married',
#        'Dependents_0', 'Dependents_1', 'Dependents_2', 'Dependents_3+',
#        'Education', 'Self_Employed', 'Property_Area_Rural',
#        'Property_Area_Semiurban', 'Property_Area_Urban', 'Loan_Status'],
#       dtype='object')

# %%
y_pred = model.predict(X_test)

# Convert ndarray back to DataFrame
X_test_df = pd.DataFrame(X_test, columns=df.columns[:-1])
X_test_df['Gender_Married'] = X_test_df['Gender'].map({1: 'male', 0: 'female'}) + '_' + X_test_df['Married'].map({1: 'married', 0: 'unmarried'})
# Build the of information to pass to Aequitas
pred_data = X_test_df.filter(items=["Gender","Married", "Gender_Married"])
pred_data['score'] = y_pred
# Reset index of pred_data
pred_data.reset_index(drop=True, inplace=True)
y_test.reset_index(drop=True, inplace=True)
pred_data['label_value'] = y_test



# Score and label_value are boolean by default, and we need them to be int
pred_data['score'] = pred_data['score'].astype('int')
pred_data['label_value'] = pred_data['label_value'].astype('int')
pred_data
# Out:
#      Gender  Married    Gender_Married  score  label_value
# 0       0.0      0.0  female_unmarried      0            0
# 1       1.0      1.0      male_married      0            1
# 2       1.0      1.0      male_married      0            0
# 3       1.0      1.0      male_married      1            1
# 4       1.0      1.0      male_married      0            0
# ..      ...      ...               ...    ...          ...
# 124     1.0      1.0      male_married      0            0
# 125     1.0      1.0      male_married      1            1
# 126     1.0      0.0    male_unmarried      1            0
# 127     1.0      1.0      male_married      0            0
# 128     1.0      1.0      male_married      1            1
#
# [129 rows x 5 columns]

# %%
#@markdown Set the color palette; very optional
aq_palette = sns.diverging_palette(225, 35, n=2)

# %%
label_by_gender = sns.countplot(x="Gender", hue="label_value", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Actual Eligibility by Gender")
# Out:
# Text(0.5, 1.0, 'Bar Plot of Actual Eligibility by Gender')

# %%
score_gender = sns.countplot(x="Gender", hue="score", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Predicted Eligibility by Gender")
# Out:
# Text(0.5, 1.0, 'Bar Plot of Predicted Eligibility by Gender')

# %%
label_by_married = sns.countplot(x="Married", hue="label_value", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Actual Eligibility by Marraige Status")
# Out:
# Text(0.5, 1.0, 'Bar Plot of Actual Eligibility by Marraige Status')

# %%
score_married = sns.countplot(x="Married", hue="score", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Predicted Eligibility by Marraige Status")
# Out:
# Text(0.5, 1.0, 'Bar Plot of Predicted Eligibility by Marraige Status')

# %%
label_by_gender_married = sns.countplot(x="Gender_Married", hue="label_value", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Actual Eligibility by Gender_Married")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'female_unmarried'),
#   Text(1, 0, 'male_married'),
#   Text(2, 0, 'male_unmarried'),
#   Text(3, 0, 'female_married')])

# %%
score_gender_married = sns.countplot(x="Gender_Married", hue="score", data=pred_data, palette=aq_palette)
plt.title("Bar Plot of Predicted Eligibility by Gender_Married")
plt.xticks(rotation=45)
# Out:
# ([0, 1, 2, 3],
#  [Text(0, 0, 'female_unmarried'),
#   Text(1, 0, 'male_married'),
#   Text(2, 0, 'male_unmarried'),
#   Text(3, 0, 'female_married')])

# %%
pred_data['Gender'] = pred_data['Gender'].astype('bool')
pred_data['Married'] = pred_data['Married'].astype('bool')
pred_data['Gender'] = pred_data['Gender'].map({True: 'male', False: 'female'})
pred_data['Married'] = pred_data['Married'].map({True: 'married', False: 'unmarried'})

# %%
pred_data
# Out:
#      Gender    Married    Gender_Married  score  label_value
# 0    female  unmarried  female_unmarried      0            0
# 1      male    married      male_married      0            1
# 2      male    married      male_married      0            0
# 3      male    married      male_married      1            1
# 4      male    married      male_married      0            0
# ..      ...        ...               ...    ...          ...
# 124    male    married      male_married      0            0
# 125    male    married      male_married      1            1
# 126    male  unmarried    male_unmarried      1            0
# 127    male    married      male_married      0            0
# 128    male    married      male_married      1            1
#
# [129 rows x 5 columns]

# %%
g = Group()
xtab, _ = g.get_crosstabs(pred_data)

# %%
absolute_metrics = g.list_absolute_metrics(xtab)
xtab[[col for col in xtab.columns if col not in absolute_metrics]]
# Out:
#    model_id score_threshold   k  attribute_name   attribute_value  pp  pn  fp  \
# 0         0      binary 0/1  61          Gender            female  10  12   4
# 1         0      binary 0/1  61          Gender              male  51  56   7
# 2         0      binary 0/1  61         Married           married  37  49   3
# 3         0      binary 0/1  61         Married         unmarried  24  19   8
# 4         0      binary 0/1  61  Gender_Married    female_married   2   2   1
# 5         0      binary 0/1  61  Gender_Married  female_unmarried   8  10   3
# 6         0      binary 0/1  61  Gender_Married      male_married  35  47   2
# 7         0      binary 0/1  61  Gender_Married    male_unmarried  16   9   5
#
#    fn  tn  tp  group_label_pos  group_label_neg  group_size  total_entities
# 0   4   8   6               10               12          22             129
# 1   8  48  44               52               55         107             129
# ...

# %% [markdown]
# Aequitas uses some names and acronyms unlike what we have used in class:
#
# precision is PPV
# ppr  =PP𝐺𝑃  where  𝑃  is the total number of people predicted positive across all groups, and  PP𝐺  is the number of people in group  𝐺  predicted positive.
# pprev is the Selection Rate
# prev is the Prevalence

# %%
#@markdown View calculated "absolute metrics" (like false positive rates) for each group
xtab[['attribute_name', 'attribute_value'] + absolute_metrics].round(2)
# Out:
#    attribute_name   attribute_value  accuracy   tpr   tnr   for   fdr   fpr  \
# 0          Gender            female      0.64  0.60  0.67  0.33  0.40  0.33
# 1          Gender              male      0.86  0.85  0.87  0.14  0.14  0.13
# 2         Married           married      0.88  0.83  0.93  0.14  0.08  0.07
# 3         Married         unmarried      0.70  0.76  0.64  0.26  0.33  0.36
# 4  Gender_Married    female_married      0.50  0.50  0.50  0.50  0.50  0.50
# 5  Gender_Married  female_unmarried      0.67  0.62  0.70  0.30  0.38  0.30
# 6  Gender_Married      male_married      0.90  0.85  0.95  0.13  0.06  0.05
# 7  Gender_Married    male_unmarried      0.72  0.85  0.58  0.22  0.31  0.42
#
#     fnr   npv  precision   ppr  pprev  prev
# 0  0.40  0.67       0.60  0.16   0.45  0.45
# 1  0.15  0.86       0.86  0.84   0.48  0.49
# 2  0.17  0.86       0.92  0.61   0.43  0.48
# 3  0.24  0.74       0.67  0.39   0.56  0.49
# 4  0.50  0.50       0.50  0.03   0.50  0.50
# ...

# %%
aqp = Plot()
fnr = aqp.plot_group_metric(xtab, 'ppr')

# %%
fnr = aqp.plot_group_metric(xtab, 'tpr') #recall

# %%
fnr = aqp.plot_group_metric(xtab, 'fpr')

# %%
fnr = aqp.plot_group_metric(xtab, 'fnr')

# %%
p = aqp.plot_group_metric_all(xtab, metrics=['pprev','fpr','fdr'], ncols=3)

# %%
# def calculate_disparate_impact(df, protected_group, outcome_column):
#     privileged_group = df[df[protected_group] == 'married']
#     unprivileged_group = df[df[protected_group] == 'unmarried']

#     privileged_positive_rate = privileged_group[outcome_column].mean()
#     unprivileged_positive_rate = unprivileged_group[outcome_column].mean()

#     return unprivileged_positive_rate / privileged_positive_rate

# def calculate_calibration(df, predicted_proba_column, outcome_column, bins=10):
#     df['bin'] = pd.qcut(df[predicted_proba_column], bins, duplicates='drop')
#     mean_predicted_proba = df.groupby('bin')[predicted_proba_column].mean()
#     mean_actual_outcome = df.groupby('bin')[outcome_column].mean()

#     calibration_loss = np.abs(mean_actual_outcome - mean_predicted_proba).mean()
#     expected_calibration_error = np.sqrt(((mean_actual_outcome - mean_predicted_proba)**2).mean())

#     return calibration_loss, expected_calibration_error

# def calculate_predictive_parity(df, protected_group, predicted_proba_column, outcome_column):
#     privileged_group = df[df[protected_group] == 'married']
#     unprivileged_group = df[df[protected_group] == 'unmarried']

#     privileged_positive_rate = privileged_group[outcome_column].mean()
#     unprivileged_positive_rate = unprivileged_group[outcome_column].mean()

#     privileged_predicted_positive_rate = privileged_group[predicted_proba_column].mean()
#     unprivileged_predicted_positive_rate = unprivileged_group[predicted_proba_column].mean()

#     return np.abs(privileged_positive_rate - privileged_predicted_positive_rate), np.abs(unprivileged_positive_rate - unprivileged_predicted_positive_rate)

# def calculate_false_discovery_rate(df, predicted_proba_column, outcome_column, threshold=0.5):
#     predicted_positive = df[df[predicted_proba_column] >= threshold]
#     false_positives = predicted_positive[predicted_positive[outcome_column] == 0]

#     return len(false_positives) / len(predicted_positive)

# # Usage example
# disparate_impact = calculate_disparate_impact(pred_data, 'Married', 'label_value')
# print("Disparate Impact:", disparate_impact)

# calibration_loss, expected_calibration_error = calculate_calibration(pred_data, 'score', 'label_value')
# print("Calibration Loss:", calibration_loss)
# print("Expected Calibration Error:", expected_calibration_error)

# privileged_predictive_parity, unprivileged_predictive_parity = calculate_predictive_parity(pred_data, 'Married', 'score', 'label_value')
# print("Privileged Predictive Parity:", privileged_predictive_parity)
# print("Unprivileged Predictive Parity:", unprivileged_predictive_parity)

# fdr = calculate_false_discovery_rate(pred_data, 'score', 'label_value')
# print("False Discovery Rate:", fdr)
# Out:
# Disparate Impact: 1.024390243902439
# Calibration Loss: 0.007751937984496138
# Expected Calibration Error: 0.007751937984496138
# Privileged Predictive Parity: 0.04651162790697677
# Unprivileged Predictive Parity: 0.06976744186046513
# False Discovery Rate: 0.18032786885245902

# %% [markdown]
# If the False Discovery Rate (FDR) is significantly higher for unmarried individuals compared to married individuals, it means that the model is more likely to incorrectly approve loans for unmarried applicants who are not creditworthy. This could be due to data bias, inadequate representation of unmarried applicants' creditworthiness in the features, or inherent biases in the model. Higher FDR for unmarried applicants poses financial risks for the lending institution and may result in unfair treatment for this demographic group. To address this, balancing training data, improving feature representation, and regularly assessing model fairness are essential steps.

# %% [markdown]
# Higher FPR for Unmarried Group:
# The False Positive Rate (FPR) measures the proportion of actual negative cases that are incorrectly classified as positive by the model. In the context of loan eligibility prediction, it represents the rate at which individuals who should not be granted a loan are mistakenly approved.
# If the FPR is significantly higher for the unmarried group compared to the married group, it suggests that the model is more prone to incorrectly approving loans for unmarried individuals.

# %% [markdown]
# Higher FPR for Females: This means that the model is incorrectly classifying more female applicants as creditworthy (positive) when they are actually not, leading to a higher rate of false approvals or loans being granted to individuals who should not receive them.
# In other words, a higher FPR for females suggests that the model is more likely to mistakenly approve loans for female applicants who may default, resulting in higher financial risks for the lending institution.
